# %% [markdown]
# ## Week 2 Day 1
#
# Our first look at the Google Gemini API.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/gemini.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The Google Gemini API Docs</h2>
#             <span style="color:#00bfff;">The documentation for the Gemini API is here: <a href="https://ai.google.dev/gemini-api/docs">https://ai.google.dev/gemini-api/docs</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from google import genai
from google.genai import types
import os

# %%
# The usual starting point

load_dotenv(override=True)

# %%
# Initialize the client
client = genai.Client()

# Generate content
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=['Tell a joke about Autonomous AI Agents'],
    config=types.GenerateContentConfig(
        system_instruction='You are a joke teller'
    )
)

print(response.text)
